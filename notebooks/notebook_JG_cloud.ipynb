# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../raw_data/sales_train_validation.csv")

# %%
df
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# 0         CA_1       CA    0    0    0    0  ...       1       3       0
# 1         CA_1       CA    0    0    0    0  ...       0       0       0
# 2         CA_1       CA    0    0    0    0  ...       2       1       2
# 3         CA_1       CA    0    0    0    0  ...       1       0       5
# 4         CA_1       CA    0    0    0    0  ...       2       1       1
# ...        ...      ...  ...  ...  ...  ...  ...     ...     ...     ...
# 30485     WI_3       WI    0    0    2    2  ...       2       0       0
# 30486     WI_3       WI    0    0    0    0  ...       0       0       0
# 30487     WI_3       WI    0    6    0    2  ...       2       1       0
# 30488     WI_3       WI    0    0    0    0  ...       0       0       1
# 30489     WI_3       WI    0    0    0    0  ...       0       0       0
#
#        d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 0           1       1       1       3       0       1       1
# 1           0       0       1       0       0       0       0
# 2           1       1       1       0       1       1       1
# 3           4       1       0       1       3       7       2
# 4           0       1       1       2       2       2       4
# ...       ...     ...     ...     ...     ...     ...     ...
# 30485       0       0       0       1       0       0       1
# 30486       0       0       0       0       0       1       0
# 30487       2       0       1       0       0       1       0
# 30488       0       0       1       0       3       1       3
# 30489       0       0       0       0       0       0       0
#
# [30490 rows x 1919 columns]

# %%
calendar_df = pd.read_csv("../raw_data/calendar.csv")

# %%
calendar_df
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0              NaN          NaN           NaN          NaN        0        0
# 1              NaN          NaN           NaN          NaN        0        0
# 2              NaN          NaN           NaN          NaN        0        0
# 3              NaN          NaN           NaN          NaN        1        1
# 4              NaN          NaN           NaN          NaN        1        0
# ...            ...          ...           ...          ...      ...      ...
# 1964           NaN          NaN           NaN          NaN        0        1
# 1965           NaN          NaN           NaN          NaN        0        0
# 1966           NaN          NaN           NaN          NaN        0        0
# 1967           NaN          NaN           NaN          NaN        0        0
# 1968  NBAFinalsEnd     Sporting  Father's day     Cultural        0        0
#
#       snap_WI
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 1964        1
# 1965        0
# 1966        0
# 1967        0
# 1968        0
#
# [1969 rows x 14 columns]

# %%
oneproduct_df = df.iloc[5500,:]

# %%
oneproduct_df = oneproduct_df.reset_index()

# %%
oneproduct_df
# Out:
#          index                         5500
# 0           id  FOODS_3_227_CA_2_validation
# 1      item_id                  FOODS_3_227
# 2      dept_id                      FOODS_3
# 3       cat_id                        FOODS
# 4     store_id                         CA_2
# ...        ...                          ...
# 1914    d_1909                            2
# 1915    d_1910                            2
# 1916    d_1911                            2
# 1917    d_1912                            4
# 1918    d_1913                            5
#
# [1919 rows x 2 columns]

# %%
oneproduct_df.columns = ['d', 'value']

# %%
# Perform the left join
merged_df = oneproduct_df.merge(calendar_df, on='d', how='left')

# %%
merged_df
# Out:
#              d                        value        date  wm_yr_wk    weekday  \
# 0           id  FOODS_3_227_CA_2_validation         NaN       NaN        NaN
# 1      item_id                  FOODS_3_227         NaN       NaN        NaN
# 2      dept_id                      FOODS_3         NaN       NaN        NaN
# 3       cat_id                        FOODS         NaN       NaN        NaN
# 4     store_id                         CA_2         NaN       NaN        NaN
# ...        ...                          ...         ...       ...        ...
# 1914    d_1909                            2  2016-04-20   11612.0  Wednesday
# 1915    d_1910                            2  2016-04-21   11612.0   Thursday
# 1916    d_1911                            2  2016-04-22   11612.0     Friday
# 1917    d_1912                            4  2016-04-23   11613.0   Saturday
# 1918    d_1913                            5  2016-04-24   11613.0     Sunday
#
#       wday  month    year event_name_1 event_type_1 event_name_2 event_type_2  \
# 0      NaN    NaN     NaN          NaN          NaN          NaN          NaN
# 1      NaN    NaN     NaN          NaN          NaN          NaN          NaN
# 2      NaN    NaN     NaN          NaN          NaN          NaN          NaN
# 3      NaN    NaN     NaN          NaN          NaN          NaN          NaN
# 4      NaN    NaN     NaN          NaN          NaN          NaN          NaN
# ...    ...    ...     ...          ...          ...          ...          ...
# 1914   5.0    4.0  2016.0          NaN          NaN          NaN          NaN
# 1915   6.0    4.0  2016.0          NaN          NaN          NaN          NaN
# 1916   7.0    4.0  2016.0          NaN          NaN          NaN          NaN
# 1917   1.0    4.0  2016.0          NaN          NaN          NaN          NaN
# 1918   2.0    4.0  2016.0          NaN          NaN          NaN          NaN
#
#       snap_CA  snap_TX  snap_WI
# 0         NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 2         NaN      NaN      NaN
# 3         NaN      NaN      NaN
# 4         NaN      NaN      NaN
# ...       ...      ...      ...
# 1914      0.0      0.0      0.0
# 1915      0.0      0.0      0.0
# 1916      0.0      0.0      0.0
# 1917      0.0      0.0      0.0
# 1918      0.0      0.0      0.0
#
# [1919 rows x 15 columns]

# %%
price_df = pd.read_csv("../raw_data/sell_prices.csv")

# %%
price_df
# Out:
#         store_id        item_id  wm_yr_wk  sell_price
# 0           CA_1  HOBBIES_1_001     11325        9.58
# 1           CA_1  HOBBIES_1_001     11326        9.58
# 2           CA_1  HOBBIES_1_001     11327        8.26
# 3           CA_1  HOBBIES_1_001     11328        8.26
# 4           CA_1  HOBBIES_1_001     11329        8.26
# ...          ...            ...       ...         ...
# 6841116     WI_3    FOODS_3_827     11617        1.00
# 6841117     WI_3    FOODS_3_827     11618        1.00
# 6841118     WI_3    FOODS_3_827     11619        1.00
# 6841119     WI_3    FOODS_3_827     11620        1.00
# 6841120     WI_3    FOODS_3_827     11621        1.00
#
# [6841121 rows x 4 columns]

# %%
price_df["wm_yr_wk"].nunique()
# Out:
# 282

# %%
# Perform the left join
merged_final_df = merged_df.merge(price_df, on='wm_yr_wk', how='left')
