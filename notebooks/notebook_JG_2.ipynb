# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../raw_data/cleaned_merge_df.csv")
# Out:
# /tmp/ipykernel_52471/85191857.py:1: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../raw_data/cleaned_merge_df.csv")

# %%
df[df["id"]=="FOODS_3_180_CA_1_validation"]
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 200     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 400     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 600     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 800     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 381600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
#
#        state_id       d  sales  wm_yr_wk    weekday  wday event_name_1  \
# 0            CA     d_1      0     11101   Saturday     1            0
# 200          CA     d_2      0     11101     Sunday     2            0
# 400          CA     d_3      0     11101     Monday     3            0
# 600          CA     d_4      0     11101    Tuesday     4            0
# 800          CA     d_5      0     11101  Wednesday     5            0
# ...         ...     ...    ...       ...        ...   ...          ...
# 381600       CA  d_1909      0     11612  Wednesday     5            0
# 381800       CA  d_1910      0     11612   Thursday     6            0
# 382000       CA  d_1911      0     11612     Friday     7            0
# 382200       CA  d_1912      1     11613   Saturday     1            0
# 382400       CA  d_1913      0     11613     Sunday     2            0
#
#        event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0                 0            0            0        0        0        0
# 200               0            0            0        0        0        0
# 400               0            0            0        0        0        0
# 600               0            0            0        1        1        0
# 800               0            0            0        1        0        1
# ...             ...          ...          ...      ...      ...      ...
# 381600            0            0            0        0        0        0
# 381800            0            0            0        0        0        0
# 382000            0            0            0        0        0        0
# 382200            0            0            0        0        0        0
# 382400            0            0            0        0        0        0
#
#         sell_price
# 0             0.00
# 200           0.00
# 400           0.00
# 600           0.00
# 800           0.00
# ...            ...
# 381600        2.98
# 381800        2.98
# 382000        2.98
# 382200        2.98
# 382400        2.98
#
# [1913 rows x 19 columns]

# %%
def rmsse(train, test, forecast):
    forecast_mse = np.mean((test - forecast)**2, axis=1)
    train_mse = [np.mean((np.diff(np.trim_zeros(row))**2)) for row in train]
    return np.sqrt(forecast_mse / train_mse)

# %%
oneproduct = df[df["id"]=="FOODS_3_180_CA_1_validation"]

# %%
oneproduct
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 200     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 400     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 600     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 800     FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 381600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
#
#        state_id       d  sales  wm_yr_wk    weekday  wday event_name_1  \
# 0            CA     d_1      0     11101   Saturday     1            0
# 200          CA     d_2      0     11101     Sunday     2            0
# 400          CA     d_3      0     11101     Monday     3            0
# 600          CA     d_4      0     11101    Tuesday     4            0
# 800          CA     d_5      0     11101  Wednesday     5            0
# ...         ...     ...    ...       ...        ...   ...          ...
# 381600       CA  d_1909      0     11612  Wednesday     5            0
# 381800       CA  d_1910      0     11612   Thursday     6            0
# 382000       CA  d_1911      0     11612     Friday     7            0
# 382200       CA  d_1912      1     11613   Saturday     1            0
# 382400       CA  d_1913      0     11613     Sunday     2            0
#
#        event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0                 0            0            0        0        0        0
# 200               0            0            0        0        0        0
# 400               0            0            0        0        0        0
# 600               0            0            0        1        1        0
# 800               0            0            0        1        0        1
# ...             ...          ...          ...      ...      ...      ...
# 381600            0            0            0        0        0        0
# 381800            0            0            0        0        0        0
# 382000            0            0            0        0        0        0
# 382200            0            0            0        0        0        0
# 382400            0            0            0        0        0        0
#
#         sell_price
# 0             0.00
# 200           0.00
# 400           0.00
# 600           0.00
# 800           0.00
# ...            ...
# 381600        2.98
# 381800        2.98
# 382000        2.98
# 382200        2.98
# 382400        2.98
#
# [1913 rows x 19 columns]

# %%
# Calculate the split index
index = len(oneproduct) - 28  # The last index minus 28 days
# Split the data
df_train_oneproduct = oneproduct.iloc[:index]
df_test_oneproduct = oneproduct.iloc[index:]
# Check the length of training and test sets
print("Number of days in df_train:", len(df_train_oneproduct))
print("Number of days in df_test:", len(df_test_oneproduct))
# Out:
# Number of days in df_train: 1885
# Number of days in df_test: 28

# %%
df_test_oneproduct
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 377000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 377200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 377400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 377600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 377800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 378000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 378200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 378400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 378600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 378800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 379000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 379200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 379400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 379600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 379800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 380000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 380200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 380400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 380600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 380800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381600  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 381800  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382000  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382200  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
# 382400  FOODS_3_180_CA_1_validation  FOODS_3_180  FOODS_3  FOODS     CA_1
#
#        state_id       d  sales  wm_yr_wk    weekday  wday event_name_1  \
# 377000       CA  d_1886      2     11609     Monday     3            0
# 377200       CA  d_1887      0     11609    Tuesday     4            0
# 377400       CA  d_1888      0     11609  Wednesday     5            0
