# %% [markdown]
# # Ranking top sellers to worst sellers, finding top selling products - Ranking of locations in number sales

# %%
import numpy as np
import pandas as pd
import csv

# %%
#csv_file_path = 
train_df = pd.read_csv('../raw_data/sales_train_validation.csv')
prices_df = pd.read_csv('../raw_data/sell_prices.csv')
calendar_df = pd.read_csv('../raw_data/calendar.csv')
merge_df = pd.read_csv('../raw_data/merge_df.csv')
# Out:
# /tmp/ipykernel_224459/1663201285.py:5: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   merge_df = pd.read_csv('../raw_data/merge_df.csv')

# %%
merge_df
# Out:
#                                      id          item_id      dept_id  \
# 0           FOODS_3_180_CA_1_validation      FOODS_3_180      FOODS_3
# 1       HOUSEHOLD_2_383_CA_3_validation  HOUSEHOLD_2_383  HOUSEHOLD_2
# 2           FOODS_3_409_CA_3_validation      FOODS_3_409      FOODS_3
# 3           FOODS_1_097_CA_2_validation      FOODS_1_097      FOODS_1
# 4         HOBBIES_1_272_TX_2_validation    HOBBIES_1_272    HOBBIES_1
# ...                                 ...              ...          ...
# 382595  HOUSEHOLD_1_314_WI_2_validation  HOUSEHOLD_1_314  HOUSEHOLD_1
# 382596      FOODS_2_126_CA_4_validation      FOODS_2_126      FOODS_2
# 382597      FOODS_1_177_TX_1_validation      FOODS_1_177      FOODS_1
# 382598      FOODS_3_356_WI_2_validation      FOODS_3_356      FOODS_3
# 382599      FOODS_3_072_CA_3_validation      FOODS_3_072      FOODS_3
#
#            cat_id store_id state_id       d  sales        date  wm_yr_wk  ...  \
# 0           FOODS     CA_1       CA     d_1      0  2011-01-29     11101  ...
# 1       HOUSEHOLD     CA_3       CA     d_1      2  2011-01-29     11101  ...
# 2           FOODS     CA_3       CA     d_1      0  2011-01-29     11101  ...
# 3           FOODS     CA_2       CA     d_1      0  2011-01-29     11101  ...
# 4         HOBBIES     TX_2       TX     d_1      0  2011-01-29     11101  ...
# ...           ...      ...      ...     ...    ...         ...       ...  ...
# 382595  HOUSEHOLD     WI_2       WI  d_1913      0  2016-04-24     11613  ...
# 382596      FOODS     CA_4       CA  d_1913      1  2016-04-24     11613  ...
# 382597      FOODS     TX_1       TX  d_1913      0  2016-04-24     11613  ...
# 382598      FOODS     WI_2       WI  d_1913      0  2016-04-24     11613  ...
# 382599      FOODS     CA_3       CA  d_1913      3  2016-04-24     11613  ...
#
#        month  year  event_name_1  event_type_1 event_name_2 event_type_2  \
# 0          1  2011           NaN           NaN          NaN          NaN
# 1          1  2011           NaN           NaN          NaN          NaN
# 2          1  2011           NaN           NaN          NaN          NaN
# 3          1  2011           NaN           NaN          NaN          NaN
# 4          1  2011           NaN           NaN          NaN          NaN
# ...      ...   ...           ...           ...          ...          ...
# 382595     4  2016           NaN           NaN          NaN          NaN
# 382596     4  2016           NaN           NaN          NaN          NaN
# 382597     4  2016           NaN           NaN          NaN          NaN
# 382598     4  2016           NaN           NaN          NaN          NaN
# 382599     4  2016           NaN           NaN          NaN          NaN
#
#        snap_CA snap_TX  snap_WI  sell_price
# 0            0       0        0         NaN
# 1            0       0        0        3.97
# 2            0       0        0         NaN
# 3            0       0        0         NaN
# 4            0       0        0         NaN
# ...        ...     ...      ...         ...
# 382595       0       0        0        7.98
# 382596       0       0        0        4.88
# 382597       0       0        0        8.98
# 382598       0       0        0        3.00
# 382599       0       0        0        2.50
#
# [382600 rows x 22 columns]
