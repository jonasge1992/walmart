# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import time
import math
import datetime

# %% [markdown]
# # CLEANING DATA FROM MERGED DATASETS

# %% [markdown]
# # LOADING MERGE_DF

# %%
import pandas as pd
merge_df = pd.read_csv('../raw_data/merge_df.csv')
merge_df
# Out:
# /var/tmp/ipykernel_4989/1322377706.py:2: DtypeWarning: Columns (14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   merge_df = pd.read_csv('../raw_data/merge_df.csv')
#                                     id        item_id    dept_id   cat_id  \
# 0        HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1        HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2        HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3        HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4        HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                                ...            ...        ...      ...
# 9170917    FOODS_1_131_CA_2_validation    FOODS_1_131    FOODS_1    FOODS
# 9170918    FOODS_1_132_CA_2_validation    FOODS_1_132    FOODS_1    FOODS
# 9170919    FOODS_1_133_CA_2_validation    FOODS_1_133    FOODS_1    FOODS
# 9170920    FOODS_1_134_CA_2_validation    FOODS_1_134    FOODS_1    FOODS
# 9170921    FOODS_1_135_CA_2_validation    FOODS_1_135    FOODS_1    FOODS
#
#         store_id state_id       d  sales        date  wm_yr_wk  ... month  \
# 0           CA_1       CA     d_1    0.0  2011-01-29     11101  ...     1
# 1           CA_1       CA     d_1    0.0  2011-01-29     11101  ...     1
# 2           CA_1       CA     d_1    0.0  2011-01-29     11101  ...     1
# 3           CA_1       CA     d_1    0.0  2011-01-29     11101  ...     1
# 4           CA_1       CA     d_1    0.0  2011-01-29     11101  ...     1
# ...          ...      ...     ...    ...         ...       ...  ...   ...
# 9170917     CA_2       CA  d_1913    0.0  2016-04-24     11613  ...     4
# 9170918     CA_2       CA  d_1913    1.0  2016-04-24     11613  ...     4
# 9170919     CA_2       CA  d_1913    1.0  2016-04-24     11613  ...     4
# 9170920     CA_2       CA  d_1913    0.0  2016-04-24     11613  ...     4
# 9170921     CA_2       CA  d_1913    NaN  2016-04-24     11613  ...     4
#
#          year  event_name_1  event_type_1 event_name_2 event_type_2 snap_CA  \
# 0        2011           NaN           NaN          NaN          NaN       0
# 1        2011           NaN           NaN          NaN          NaN       0
# 2        2011           NaN           NaN          NaN          NaN       0
# 3        2011           NaN           NaN          NaN          NaN       0
# 4        2011           NaN           NaN          NaN          NaN       0
# ...       ...           ...           ...          ...          ...     ...
# 9170917  2016           NaN           NaN          NaN          NaN       0
# 9170918  2016           NaN           NaN          NaN          NaN       0
# 9170919  2016           NaN           NaN          NaN          NaN       0
# 9170920  2016           NaN           NaN          NaN          NaN       0
# 9170921  2016           NaN           NaN          NaN          NaN       0
#
#         snap_TX  snap_WI  sell_price
# 0             0        0         NaN
# 1             0        0         NaN
# 2             0        0         NaN
# 3             0        0         NaN
# 4             0        0         NaN
# ...         ...      ...         ...
# 9170917       0        0         NaN
# 9170918       0        0         NaN
# 9170919       0        0         NaN
# 9170920       0        0         NaN
# 9170921       0        0         NaN
#
# [9170922 rows x 22 columns]

# %% [markdown]
# # DETECT MISSING VALUES

# %%
missing_values = merge_df.isnull().sum()
print(missing_values)
# Out:
# id                    0
# item_id               0
# dept_id               0
# cat_id                0
# store_id              0
# state_id              0
# d                     0
# sales               596
# date                  0
# wm_yr_wk              0
# weekday               0
# wday                  0
# month                 0
# year                  0
# event_name_1    8432646
# event_type_1    8432646
# event_name_2    9151746
# event_type_2    9151746
# snap_CA               0
# snap_TX               0
# snap_WI               0
# sell_price      4921203
# dtype: int64

# %%
#CHECKING MISSING VALUES AGAIN
missing_values = merge_df.isnull().sum()
print(missing_values)
# Out:
# id                    0
# item_id               0
# dept_id               0
# cat_id                0
# store_id              0
# state_id              0
# d                     0
# sales               596
# date                  0
# wm_yr_wk              0
# weekday               0
# wday                  0
# month                 0
# year                  0
# event_name_1    8432646
# event_type_1    8432646
# event_name_2    9151746
# event_type_2    9151746
# snap_CA               0
# snap_TX               0
# snap_WI               0
# sell_price      4921203
# dtype: int64

# %% [markdown]
# ### CHECKING DUPLICATED ROWS

# %%
duplicated_rows = merge_df[merge_df.duplicated()]

print("Duplicated rows:")
print(duplicated_rows)
# Out:
# Duplicated rows:
# Empty DataFrame
# Columns: [id, item_id, dept_id, cat_id, store_id, state_id, d, sales, date, wm_yr_wk, weekday, wday, month, year, event_name_1, event_type_1, event_name_2, event_type_2, snap_CA, snap_TX, snap_WI, sell_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
#NO DUPLICATED ROWS

# %% [markdown]
# # MISSING DATES

# %%
star_date = '2011-01-29'
end_date = '2016-06-19'

# Generate the dates
expected_dates = pd.date_range(start=star_date, end=end_date)

# format
merge_df['date'] = pd.to_datetime(merge_df['date'])

# extract unique dates
current_dates = merge_df['date'].dt.date.unique()

expected_dates_set = set(expected_dates)
current_dates_set = set(current_dates)

# verify
missing_dates = expected_dates_set - current_dates_set

# %% [markdown]
# ## FILLING THE MISSING DATES

# %%
import pandas as pd

# Convert the date column to datetime format, if necessary
merge_df['date'] = pd.to_datetime(merge_df['date'])

# Define the date range from January 29, 2011 to April 24, 2016
start_date = '2011-01-29'
end_date = '2016-04-24'

# Generate all dates within the range
expected_dates = pd.date_range(start=start_date, end=end_date)

# Create a DataFrame with all expected dates
expected_dates_df = pd.DataFrame({'date': expected_dates})

# Merge the expected dates DataFrame with the existing DataFrame
merge_df = pd.merge(expected_dates_df, merge_df, on='date', how='left')

# Check if there are any missing dates in the range
if merge_df['date'].isnull().any():
    print("There are still missing dates in the specified range.")
else:
    print("All missing dates have been filled correctly.")
# Out:
# All missing dates have been filled correctly.

# %%
merge_df
# Out:
#               date                             id        item_id    dept_id  \
# 0       2011-01-29  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1
# 1       2011-01-29  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1
# 2       2011-01-29  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1
# 3       2011-01-29  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1
# 4       2011-01-29  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1
# ...            ...                            ...            ...        ...
# 9170917 2016-04-24    FOODS_1_131_CA_2_validation    FOODS_1_131    FOODS_1
# 9170918 2016-04-24    FOODS_1_132_CA_2_validation    FOODS_1_132    FOODS_1
# 9170919 2016-04-24    FOODS_1_133_CA_2_validation    FOODS_1_133    FOODS_1
# 9170920 2016-04-24    FOODS_1_134_CA_2_validation    FOODS_1_134    FOODS_1
# 9170921 2016-04-24    FOODS_1_135_CA_2_validation    FOODS_1_135    FOODS_1
#
#           cat_id store_id state_id       d  sales  wm_yr_wk  ... month  year  \
# 0        HOBBIES     CA_1       CA     d_1    0.0     11101  ...     1  2011
# 1        HOBBIES     CA_1       CA     d_1    0.0     11101  ...     1  2011
# 2        HOBBIES     CA_1       CA     d_1    0.0     11101  ...     1  2011
# 3        HOBBIES     CA_1       CA     d_1    0.0     11101  ...     1  2011
# 4        HOBBIES     CA_1       CA     d_1    0.0     11101  ...     1  2011
# ...          ...      ...      ...     ...    ...       ...  ...   ...   ...
# 9170917    FOODS     CA_2       CA  d_1913    0.0     11613  ...     4  2016
# 9170918    FOODS     CA_2       CA  d_1913    1.0     11613  ...     4  2016
# 9170919    FOODS     CA_2       CA  d_1913    1.0     11613  ...     4  2016
# 9170920    FOODS     CA_2       CA  d_1913    0.0     11613  ...     4  2016
# 9170921    FOODS     CA_2       CA  d_1913    NaN     11613  ...     4  2016
#
#          event_name_1  event_type_1 event_name_2 event_type_2 snap_CA snap_TX  \
# 0                 NaN           NaN          NaN          NaN       0       0
# 1                 NaN           NaN          NaN          NaN       0       0
# 2                 NaN           NaN          NaN          NaN       0       0
# 3                 NaN           NaN          NaN          NaN       0       0
# 4                 NaN           NaN          NaN          NaN       0       0
# ...               ...           ...          ...          ...     ...     ...
# 9170917           NaN           NaN          NaN          NaN       0       0
# 9170918           NaN           NaN          NaN          NaN       0       0
# 9170919           NaN           NaN          NaN          NaN       0       0
# 9170920           NaN           NaN          NaN          NaN       0       0
# 9170921           NaN           NaN          NaN          NaN       0       0
#
#          snap_WI  sell_price
# 0              0         NaN
# 1              0         NaN
# 2              0         NaN
# 3              0         NaN
# 4              0         NaN
# ...          ...         ...
# 9170917        0         NaN
# 9170918        0         NaN
# 9170919        0         NaN
# 9170920        0         NaN
# 9170921        0         NaN
#
# [9170922 rows x 22 columns]

# %% [markdown]
# ### SET AS INDEX

# %%
# Convert the date column to datetime format, if necessary
merge_df['date'] = pd.to_datetime(merge_df['date'])

# Set the 'date' column as the DataFrame index without renaming it to 'index'
merge_df.set_index('date', inplace=True, drop=True)

# Check the index name
print("Index name:", merge_df.index.name)
# Out:
# Index name: date

# %%
merge_df
# Out:
#                                        id        item_id    dept_id   cat_id  \
# date
# 2011-01-29  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                                   ...            ...        ...      ...
# 2016-04-24    FOODS_1_131_CA_2_validation    FOODS_1_131    FOODS_1    FOODS
# 2016-04-24    FOODS_1_132_CA_2_validation    FOODS_1_132    FOODS_1    FOODS
# 2016-04-24    FOODS_1_133_CA_2_validation    FOODS_1_133    FOODS_1    FOODS
# 2016-04-24    FOODS_1_134_CA_2_validation    FOODS_1_134    FOODS_1    FOODS
# 2016-04-24    FOODS_1_135_CA_2_validation    FOODS_1_135    FOODS_1    FOODS
#
#            store_id state_id       d  sales  wm_yr_wk   weekday  ...  month  \
# date                                                             ...
# 2011-01-29     CA_1       CA     d_1    0.0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA     d_1    0.0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA     d_1    0.0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA     d_1    0.0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA     d_1    0.0     11101  Saturday  ...      1
# ...             ...      ...     ...    ...       ...       ...  ...    ...
# 2016-04-24     CA_2       CA  d_1913    0.0     11613    Sunday  ...      4
# 2016-04-24     CA_2       CA  d_1913    1.0     11613    Sunday  ...      4
# 2016-04-24     CA_2       CA  d_1913    1.0     11613    Sunday  ...      4
# 2016-04-24     CA_2       CA  d_1913    0.0     11613    Sunday  ...      4
# 2016-04-24     CA_2       CA  d_1913    NaN     11613    Sunday  ...      4
#
#             year  event_name_1 event_type_1 event_name_2 event_type_2 snap_CA  \
# date
# 2011-01-29  2011           NaN          NaN          NaN          NaN       0
# 2011-01-29  2011           NaN          NaN          NaN          NaN       0
# 2011-01-29  2011           NaN          NaN          NaN          NaN       0
# 2011-01-29  2011           NaN          NaN          NaN          NaN       0
# 2011-01-29  2011           NaN          NaN          NaN          NaN       0
# ...          ...           ...          ...          ...          ...     ...
# 2016-04-24  2016           NaN          NaN          NaN          NaN       0
# 2016-04-24  2016           NaN          NaN          NaN          NaN       0
# 2016-04-24  2016           NaN          NaN          NaN          NaN       0
# 2016-04-24  2016           NaN          NaN          NaN          NaN       0
# 2016-04-24  2016           NaN          NaN          NaN          NaN       0
#
#             snap_TX  snap_WI  sell_price
# date
# 2011-01-29        0        0         NaN
# 2011-01-29        0        0         NaN
# 2011-01-29        0        0         NaN
# 2011-01-29        0        0         NaN
# 2011-01-29        0        0         NaN
# ...             ...      ...         ...
# 2016-04-24        0        0         NaN
# 2016-04-24        0        0         NaN
# 2016-04-24        0        0         NaN
# 2016-04-24        0        0         NaN
# 2016-04-24        0        0         NaN
#
# [9170922 rows x 21 columns]

# %%
#dropping month and year because repetitive
merge_df.drop(columns=['d','wm_yr_wk'], inplace=True)

# %%
merge_df.to_csv('../raw_data/cleaned_merge_df.csv', index=True)

# %%
merge_df
# Out:
#                                        id        item_id    dept_id   cat_id  \
# date
# 2011-01-29  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                                   ...            ...        ...      ...
# 2016-04-24    FOODS_1_131_CA_2_validation    FOODS_1_131    FOODS_1    FOODS
# 2016-04-24    FOODS_1_132_CA_2_validation    FOODS_1_132    FOODS_1    FOODS
# 2016-04-24    FOODS_1_133_CA_2_validation    FOODS_1_133    FOODS_1    FOODS
# 2016-04-24    FOODS_1_134_CA_2_validation    FOODS_1_134    FOODS_1    FOODS
# 2016-04-24    FOODS_1_135_CA_2_validation    FOODS_1_135    FOODS_1    FOODS
#
#            store_id state_id  sales   weekday  wday  month  year event_name_1  \
# date
# 2011-01-29     CA_1       CA    0.0  Saturday     1      1  2011          NaN
# 2011-01-29     CA_1       CA    0.0  Saturday     1      1  2011          NaN
# 2011-01-29     CA_1       CA    0.0  Saturday     1      1  2011          NaN
# 2011-01-29     CA_1       CA    0.0  Saturday     1      1  2011          NaN
# 2011-01-29     CA_1       CA    0.0  Saturday     1      1  2011          NaN
# ...             ...      ...    ...       ...   ...    ...   ...          ...
# 2016-04-24     CA_2       CA    0.0    Sunday     2      4  2016          NaN
# 2016-04-24     CA_2       CA    1.0    Sunday     2      4  2016          NaN
# 2016-04-24     CA_2       CA    1.0    Sunday     2      4  2016          NaN
# 2016-04-24     CA_2       CA    0.0    Sunday     2      4  2016          NaN
# 2016-04-24     CA_2       CA    NaN    Sunday     2      4  2016          NaN
#
#            event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# date
# 2011-01-29          NaN          NaN          NaN        0        0        0
# 2011-01-29          NaN          NaN          NaN        0        0        0
# 2011-01-29          NaN          NaN          NaN        0        0        0
# 2011-01-29          NaN          NaN          NaN        0        0        0
# 2011-01-29          NaN          NaN          NaN        0        0        0
# ...                 ...          ...          ...      ...      ...      ...
# 2016-04-24          NaN          NaN          NaN        0        0        0
# 2016-04-24          NaN          NaN          NaN        0        0        0
# 2016-04-24          NaN          NaN          NaN        0        0        0
# 2016-04-24          NaN          NaN          NaN        0        0        0
# 2016-04-24          NaN          NaN          NaN        0        0        0
#
#             sell_price
# date
# 2011-01-29         NaN
# 2011-01-29         NaN
# 2011-01-29         NaN
# 2011-01-29         NaN
# 2011-01-29         NaN
# ...                ...
# 2016-04-24         NaN
# 2016-04-24         NaN
# 2016-04-24         NaN
# 2016-04-24         NaN
# 2016-04-24         NaN
#
# [9170922 rows x 19 columns]
