# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import time
import math
import datetime
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # CLEANING DATA FROM MERGED DATASETS

# %% [markdown]
# # LOADING MERGE_DF

# %%
import pandas as pd
merge_df = pd.read_csv('../raw_data/merge_df.csv')
merge_df.head()
# Out:
# /tmp/ipykernel_19618/47615108.py:2: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   merge_df = pd.read_csv('../raw_data/merge_df.csv')
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales        date  wm_yr_wk  ... month  year  event_name_1  \
# 0       CA  d_1     12  2011-01-29     11101  ...     1  2011           NaN
# 1       CA  d_1      4  2011-01-29     11101  ...     1  2011           NaN
# 2       CA  d_1      5  2011-01-29     11101  ...     1  2011           NaN
# 3       CA  d_1      0  2011-01-29     11101  ...     1  2011           NaN
# 4       CA  d_1      9  2011-01-29     11101  ...     1  2011           NaN
#
#    event_type_1 event_name_2 event_type_2 snap_CA snap_TX  snap_WI  sell_price
# 0           NaN          NaN          NaN       0       0        0        0.46
# 1           NaN          NaN          NaN       0       0        0        0.70
# 2           NaN          NaN          NaN       0       0        0        0.70
# 3           NaN          NaN          NaN       0       0        0         NaN
# 4           NaN          NaN          NaN       0       0        0        0.47
#
# [5 rows x 22 columns]

# %%
merge_df
# Out:
#                                    id        item_id    dept_id   cat_id  \
# 0       HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 1       HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 2       HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1  HOBBIES
# 3       HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1  HOBBIES
# 4       HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1  HOBBIES
# ...                               ...            ...        ...      ...
# 382595    FOODS_1_046_CA_2_validation    FOODS_1_046    FOODS_1    FOODS
# 382596    FOODS_1_055_CA_2_validation    FOODS_1_055    FOODS_1    FOODS
# 382597    FOODS_1_067_CA_2_validation    FOODS_1_067    FOODS_1    FOODS
# 382598    FOODS_1_085_CA_2_validation    FOODS_1_085    FOODS_1    FOODS
# 382599    FOODS_1_110_CA_2_validation    FOODS_1_110    FOODS_1    FOODS
#
#        store_id state_id       d  sales        date  wm_yr_wk  ... month  \
# 0          CA_1       CA     d_1     12  2011-01-29     11101  ...     1
# 1          CA_1       CA     d_1      4  2011-01-29     11101  ...     1
# 2          CA_1       CA     d_1      5  2011-01-29     11101  ...     1
# 3          CA_1       CA     d_1      0  2011-01-29     11101  ...     1
# 4          CA_1       CA     d_1      9  2011-01-29     11101  ...     1
# ...         ...      ...     ...    ...         ...       ...  ...   ...
# 382595     CA_2       CA  d_1913      8  2016-04-24     11613  ...     4
# 382596     CA_2       CA  d_1913      4  2016-04-24     11613  ...     4
# 382597     CA_2       CA  d_1913     15  2016-04-24     11613  ...     4
# 382598     CA_2       CA  d_1913     12  2016-04-24     11613  ...     4
# 382599     CA_2       CA  d_1913      0  2016-04-24     11613  ...     4
#
#         year  event_name_1  event_type_1 event_name_2 event_type_2 snap_CA  \
# 0       2011           NaN           NaN          NaN          NaN       0
# 1       2011           NaN           NaN          NaN          NaN       0
# 2       2011           NaN           NaN          NaN          NaN       0
# 3       2011           NaN           NaN          NaN          NaN       0
# 4       2011           NaN           NaN          NaN          NaN       0
# ...      ...           ...           ...          ...          ...     ...
# 382595  2016           NaN           NaN          NaN          NaN       0
# 382596  2016           NaN           NaN          NaN          NaN       0
# 382597  2016           NaN           NaN          NaN          NaN       0
# 382598  2016           NaN           NaN          NaN          NaN       0
# 382599  2016           NaN           NaN          NaN          NaN       0
#
#        snap_TX  snap_WI  sell_price
# 0            0        0        0.46
# 1            0        0        0.70
# 2            0        0        0.70
# 3            0        0         NaN
# 4            0        0        0.47
# ...        ...      ...         ...
# 382595       0        0        0.98
# 382596       0        0        4.38
# 382597       0        0        2.00
# 382598       0        0        0.98
# 382599       0        0        1.96
#
# [382600 rows x 22 columns]

# %% [markdown]
# # DETECT MISSING VALUES

# %%
missing_values = merge_df.isnull().sum()
print(missing_values)
# Out:
# id                   0
# item_id              0
# dept_id              0
# cat_id               0
# store_id             0
# state_id             0
# d                    0
# sales                0
# date                 0
# wm_yr_wk             0
# weekday              0
# wday                 0
# month                0
# year                 0
# event_name_1    351800
# event_type_1    351800
# event_name_2    381800
# event_type_2    381800
# snap_CA              0
# snap_TX              0
# snap_WI              0
# sell_price       22638
# dtype: int64

# %%
#FILLING THE EMPTY PLACES
merge_df['sell_price'].fillna(0, inplace=True)
merge_df['event_name_1'].fillna('missing', inplace=True)
merge_df['event_type_1'].fillna('missing', inplace=True)
merge_df['event_name_2'].fillna('missing', inplace=True)
merge_df['event_type_2'].fillna('missing', inplace=True)
# Out:
# /tmp/ipykernel_19618/1627116259.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merge_df['sell_price'].fillna(0, inplace=True)
# /tmp/ipykernel_19618/1627116259.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merge_df['event_name_1'].fillna('missing', inplace=True)
# /tmp/ipykernel_19618/1627116259.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merge_df['event_type_1'].fillna('missing', inplace=True)
# /tmp/ipykernel_19618/1627116259.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merge_df['event_name_2'].fillna('missing', inplace=True)
# /tmp/ipykernel_19618/1627116259.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merge_df['event_type_2'].fillna('missing', inplace=True)

# %%
#CHECKING MISSING VALUES AGAIN
missing_values = merge_df.isnull().sum()
print(missing_values)
# Out:
# id              0
# item_id         0
# dept_id         0
# cat_id          0
# store_id        0
# state_id        0
# d               0
# sales           0
# date            0
# wm_yr_wk        0
# weekday         0
# wday            0
# month           0
# year            0
# event_name_1    0
# event_type_1    0
# event_name_2    0
# event_type_2    0
# snap_CA         0
# snap_TX         0
# snap_WI         0
# sell_price      0
# dtype: int64

# %% [markdown]
# ### CHECKING DUPLICATED ROWS

# %%
duplicated_rows = merge_df[merge_df.duplicated()]

print("Duplicated rows:")
print(duplicated_rows)
# Out:
# Duplicated rows:
# Empty DataFrame
# Columns: [id, item_id, dept_id, cat_id, store_id, state_id, d, sales, date, wm_yr_wk, weekday, wday, month, year, event_name_1, event_type_1, event_name_2, event_type_2, snap_CA, snap_TX, snap_WI, sell_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
#NO DUPLICATED ROWS

# %% [markdown]
# # MISSING DATES

# %%
star_date = '2011-01-29'
end_date = '2016-06-19'

# Generate the dates
expected_dates = pd.date_range(start=star_date, end=end_date)

# format
merge_df['date'] = pd.to_datetime(merge_df['date'])

# extract unique dates
current_dates = merge_df['date'].dt.date.unique()

expected_dates_set = set(expected_dates)
current_dates_set = set(current_dates)

# verify
missing_dates = expected_dates_set - current_dates_set

if not missing_dates:
    print("No missing dates .")
else:
    print("there is no these dates")
    print(missing_dates)
# Out:
# there is no these dates
# {Timestamp('2012-04-13 00:00:00'), Timestamp('2015-03-30 00:00:00'), Timestamp('2015-04-27 00:00:00'), Timestamp('2012-02-12 00:00:00'), Timestamp('2014-10-06 00:00:00'), Timestamp('2011-10-11 00:00:00'), Timestamp('2011-04-03 00:00:00'), Timestamp('2014-03-20 00:00:00'), Timestamp('2016-03-22 00:00:00'), Timestamp('2012-01-17 00:00:00'), Timestamp('2014-07-29 00:00:00'), Timestamp('2012-12-18 00:00:00'), Timestamp('2014-08-09 00:00:00'), Timestamp('2014-08-01 00:00:00'), Timestamp('2016-01-30 00:00:00'), Timestamp('2014-04-29 00:00:00'), Timestamp('2015-07-16 00:00:00'), Timestamp('2011-09-10 00:00:00'), Timestamp('2012-07-19 00:00:00'), Timestamp('2014-07-11 00:00:00'), Timestamp('2012-08-25 00:00:00'), Timestamp('2012-04-26 00:00:00'), Timestamp('2013-06-10 00:00:00'), Timestamp('2012-06-21 00:00:00'), Timestamp('2012-10-29 00:00:00'), Timestamp('2013-09-05 00:00:00'), Timestamp('2011-03-18 00:00:00'), Timestamp('2014-01-09 00:00:00'), Timestamp('2012-06-30 00:00:00'), Timestamp('2012-10-15 00:00:00'), Timestamp('2016-05-14 00:00:00'), Timestamp('2013-07-31 00:00:00'), Timestamp('2012-11-09 00:00:00'), Timestamp('2014-01-14 00:00:00'), Timestamp('2016-02-21 00:00:00'), Timestamp('2015-03-31 00:00:00'), Timestamp('2014-12-09 00:00:00'), Timestamp('2011-12-07 00:00:00'), Timestamp('2012-09-15 00:00:00'), Timestamp('2012-08-06 00:00:00'), Timestamp('2013-04-06 00:00:00'), Timestamp('2013-02-03 00:00:00'), Timestamp('2015-09-23 00:00:00'), Timestamp('2012-04-20 00:00:00'), Timestamp('2015-07-04 00:00:00'), Timestamp('2014-05-01 00:00:00'), Timestamp('2014-07-23 00:00:00'), Timestamp('2015-03-16 00:00:00'), Timestamp('2012-08-04 00:00:00'), Timestamp('2011-12-11 00:00:00'), Timestamp('2015-12-06 00:00:00'), Timestamp('2013-11-24 00:00:00'), Timestamp('2011-08-30 00:00:00'), Timestamp('2011-05-28 00:00:00'), Timestamp('2014-03-27 00:00:00'), Timestamp('2014-12-25 00:00:00'), Timestamp('2011-08-12 00:00:00'), Timestamp('2015-03-18 00:00:00'), Timestamp('2012-07-15 00:00:00'), Timestamp('2014-01-27 00:00:00'), Timestamp('2014-07-02 00:00:00'), Timestamp('2015-12-11 00:00:00'), Timestamp('2012-08-13 00:00:00'), Timestamp('2014-08-13 00:00:00'), Timestamp('2014-06-21 00:00:00'), Timestamp('2012-12-04 00:00:00'), Timestamp('2015-04-18 00:00:00'), Timestamp('2015-12-04 00:00:00'), Timestamp('2015-05-26 00:00:00'), Timestamp('2015-05-15 00:00:00'), Timestamp('2015-04-19 00:00:00'), Timestamp('2014-06-16 00:00:00'), Timestamp('2015-02-17 00:00:00'), Timestamp('2015-06-21 00:00:00'), Timestamp('2014-10-24 00:00:00'), Timestamp('2015-07-10 00:00:00'), Timestamp('2013-12-20 00:00:00'), Timestamp('2016-06-01 00:00:00'), Timestamp('2011-03-11 00:00:00'), Timestamp('2014-06-29 00:00:00'), Timestamp('2015-08-03 00:00:00'), Timestamp('2015-09-24 00:00:00'), Timestamp('2012-02-18 00:00:00'), Timestamp('2011-02-14 00:00:00'), Timestamp('2015-11-10 00:00:00'), Timestamp('2014-08-05 00:00:00'), Timestamp('2013-12-10 00:00:00'), Timestamp('2013-08-23 00:00:00'), Timestamp('2016-06-13 00:00:00'), Timestamp('2014-10-29 00:00:00'), Timestamp('2013-03-21 00:00:00'), Timestamp('2011-11-27 00:00:00'), Timestamp('2013-04-11 00:00:00'), Timestamp('2015-10-04 00:00:00'), Timestamp('2013-05-11 00:00:00'), Timestamp('2013-05-25 00:00:00'), Timestamp('2012-01-22 00:00:00'), Timestamp('2016-04-04 00:00:00'), Timestamp('2016-03-27 00:00:00'), Timestamp('2011-10-30 00:00:00'), Timestamp('2011-06-26 00:00:00'), Timestamp('2013-11-03 00:00:00'), Timestamp('2014-10-28 00:00:00'), Timestamp('2014-03-08 00:00:00'), Timestamp('2013-08-31 00:00:00'), Timestamp('2011-06-11 00:00:00'), Timestamp('2013-03-12 00:00:00'), Timestamp('2013-07-01 00:00:00'), Timestamp('2013-05-29 00:00:00'), Timestamp('2012-12-30 00:00:00'), Timestamp('2012-11-06 00:00:00'), Timestamp('2011-06-28 00:00:00'), Timestamp('2011-11-09 00:00:00'), Timestamp('2014-11-11 00:00:00'), Timestamp('2014-01-28 00:00:00'), Timestamp('2012-08-09 00:00:00'), Timestamp('2011-12-08 00:00:00'), Timestamp('2011-07-09 ...

# %% [markdown]
# ## FILLING THE MISSING DATES

# %%
import pandas as pd

# Convert the date column to datetime format, if necessary
merge_df['date'] = pd.to_datetime(merge_df['date'])

# Define the date range from January 29, 2011 to April 24, 2016
start_date = '2011-01-29'
end_date = '2016-04-24'

# Generate all dates within the range
expected_dates = pd.date_range(start=start_date, end=end_date)

# Create a DataFrame with all expected dates
expected_dates_df = pd.DataFrame({'date': expected_dates})

# Merge the expected dates DataFrame with the existing DataFrame
merge_df = pd.merge(expected_dates_df, merge_df, on='date', how='left')

# Check if there are any missing dates in the range
if merge_df['date'].isnull().any():
    print("There are still missing dates in the specified range.")
else:
    print("All missing dates have been filled correctly.")
# Out:
# All missing dates have been filled correctly.

# %%
merge_df.head(5)
# Out:
#         date                             id        item_id    dept_id  \
# 0 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1
# 1 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1
# 2 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1
# 3 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1
# 4 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1
#
#     cat_id store_id state_id    d  sales  wm_yr_wk  ... month  year  \
# 0  HOBBIES     CA_1       CA  d_1     12     11101  ...     1  2011
# 1  HOBBIES     CA_1       CA  d_1      4     11101  ...     1  2011
# 2  HOBBIES     CA_1       CA  d_1      5     11101  ...     1  2011
# 3  HOBBIES     CA_1       CA  d_1      0     11101  ...     1  2011
# 4  HOBBIES     CA_1       CA  d_1      9     11101  ...     1  2011
#
#    event_name_1  event_type_1 event_name_2 event_type_2 snap_CA snap_TX  \
# 0       missing       missing      missing      missing       0       0
# 1       missing       missing      missing      missing       0       0
# 2       missing       missing      missing      missing       0       0
# 3       missing       missing      missing      missing       0       0
# 4       missing       missing      missing      missing       0       0
#
#    snap_WI  sell_price
# 0        0        0.46
# 1        0        0.70
# 2        0        0.70
# 3        0        0.00
# 4        0        0.47
#
# [5 rows x 22 columns]

# %% [markdown]
# ### SET AS INDEX

# %%
# Convert the date column to datetime format, if necessary
merge_df['date'] = pd.to_datetime(merge_df['date'])

# Set the 'date' column as the DataFrame index without renaming it to 'index'
merge_df.set_index('date', inplace=True, drop=True)

# Check the index name
print("Index name:", merge_df.index.name)
# Out:
# Index name: date

# %%
merge_df.head(5)
# Out:
#                                        id        item_id    dept_id   cat_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1  HOBBIES
#
#            store_id state_id    d  sales  wm_yr_wk   weekday  ...  month  \
# date                                                          ...
# 2011-01-29     CA_1       CA  d_1     12     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      4     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      5     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      9     11101  Saturday  ...      1
#
#             year  event_name_1 event_type_1 event_name_2 event_type_2 snap_CA  \
# date
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
#
#             snap_TX  snap_WI  sell_price
# date
# 2011-01-29        0        0        0.46
# 2011-01-29        0        0        0.70
# 2011-01-29        0        0        0.70
# 2011-01-29        0        0        0.00
# 2011-01-29        0        0        0.47
#
# [5 rows x 21 columns]

# %%
#dropping month and year because repetitive
# merge_df.drop(columns=['year','month'], inplace=True)

# %%
merge_df.to_csv('../raw_data/cleaned_merge_df.csv', index=False)

# %%
merge_df.head(5)
# Out:
#                                        id        item_id    dept_id   cat_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1  HOBBIES
#
#            store_id state_id    d  sales  wm_yr_wk   weekday  ...  month  \
# date                                                          ...
# 2011-01-29     CA_1       CA  d_1     12     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      4     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      5     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      9     11101  Saturday  ...      1
#
#             year  event_name_1 event_type_1 event_name_2 event_type_2 snap_CA  \
# date
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
# 2011-01-29  2011       missing      missing      missing      missing       0
#
#             snap_TX  snap_WI  sell_price
# date
# 2011-01-29        0        0        0.46
# 2011-01-29        0        0        0.70
# 2011-01-29        0        0        0.70
# 2011-01-29        0        0        0.00
# 2011-01-29        0        0        0.47
#
# [5 rows x 21 columns]

# %% [markdown]
# ## testing product

# %%
test_product = merge_df[merge_df['item_id']=='HOBBIES_1_272'].groupby('date').sum()

# %%
sns.lineplot(test_product['sales'])
# Out:
# <Axes: >

# %%
sns.histplot(merge_df['sell_price'], bins=200,kde = True);

# %% [markdown]
# # MinMax Scaler & OneHotEncoder

# %%
# Scale 'sell_price' and 'year' by using MinMaxScaler
minmax_scaler = MinMaxScaler()

merge_df[['sell_price']] = minmax_scaler.fit_transform(merge_df[['sell_price']])
merge_df[['year']] = minmax_scaler.fit_transform(merge_df[['year']])

# %%
merge_df.head()
# Out:
#                                        id        item_id    dept_id   cat_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1  HOBBIES
#
#            store_id state_id    d  sales  wm_yr_wk   weekday  ...  month  \
# date                                                          ...
# 2011-01-29     CA_1       CA  d_1     12     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      4     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      5     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      9     11101  Saturday  ...      1
#
#             year  event_name_1 event_type_1 event_name_2 event_type_2 snap_CA  \
# date
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
#
#             snap_TX  snap_WI  sell_price
# date
# 2011-01-29        0        0    0.065903
# 2011-01-29        0        0    0.100287
# 2011-01-29        0        0    0.100287
# 2011-01-29        0        0    0.000000
# 2011-01-29        0        0    0.067335
#
# [5 rows x 21 columns]

# %%
sns.histplot(merge_df['sell_price'], bins=200,kde = True);

# %%
merge_df.head()
# Out:
#                                        id        item_id    dept_id   cat_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1  HOBBIES
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1  HOBBIES
#
#            store_id state_id    d  sales  wm_yr_wk   weekday  ...  month  \
# date                                                          ...
# 2011-01-29     CA_1       CA  d_1     12     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      4     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      5     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      0     11101  Saturday  ...      1
# 2011-01-29     CA_1       CA  d_1      9     11101  Saturday  ...      1
#
#             year  event_name_1 event_type_1 event_name_2 event_type_2 snap_CA  \
# date
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
# 2011-01-29   0.0       missing      missing      missing      missing       0
#
#             snap_TX  snap_WI  sell_price
# date
# 2011-01-29        0        0    0.065903
# 2011-01-29        0        0    0.100287
# 2011-01-29        0        0    0.100287
# 2011-01-29        0        0    0.000000
# 2011-01-29        0        0    0.067335
#
# [5 rows x 21 columns]

# %%
# Check unique values
print(f"The unique values for 'cat_id' are {merge_df['cat_id'].unique()}")

# Instantiate the OneHotEncoder
ohe = OneHotEncoder(sparse_output = False) 

# Fit encoder
ohe.fit(merge_df[['cat_id']]) 

# Display the detected categories
print(f"The categories detected by the OneHotEncoder are {ohe.categories_}")

# Display the generated names
print(f"The column names for the encoded values are {ohe.get_feature_names_out()}")

# Transform the current "cat_id" column
merge_df[ohe.get_feature_names_out()] = ohe.transform(merge_df[['cat_id']])

# Drop the column "cat_id" which has been encoded
merge_df.drop(columns = ['cat_id'], inplace = True)
# Out:
# The unique values for 'cat_id' are ['HOBBIES' 'HOUSEHOLD' 'FOODS']
# The categories detected by the OneHotEncoder are [array(['FOODS', 'HOBBIES', 'HOUSEHOLD'], dtype=object)]
# The column names for the encoded values are ['cat_id_FOODS' 'cat_id_HOBBIES' 'cat_id_HOUSEHOLD']

# %%
merge_df.head()
# Out:
#                                        id        item_id    dept_id store_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1     CA_1
#
#            state_id    d  sales  wm_yr_wk   weekday  wday  ...  event_type_1  \
# date                                                       ...
# 2011-01-29       CA  d_1     12     11101  Saturday     1  ...       missing
# 2011-01-29       CA  d_1      4     11101  Saturday     1  ...       missing
# 2011-01-29       CA  d_1      5     11101  Saturday     1  ...       missing
# 2011-01-29       CA  d_1      0     11101  Saturday     1  ...       missing
# 2011-01-29       CA  d_1      9     11101  Saturday     1  ...       missing
#
#             event_name_2 event_type_2 snap_CA snap_TX snap_WI  sell_price  \
# date
# 2011-01-29       missing      missing       0       0       0    0.065903
# 2011-01-29       missing      missing       0       0       0    0.100287
# 2011-01-29       missing      missing       0       0       0    0.100287
# 2011-01-29       missing      missing       0       0       0    0.000000
# 2011-01-29       missing      missing       0       0       0    0.067335
#
#             cat_id_FOODS  cat_id_HOBBIES  cat_id_HOUSEHOLD
# date
# 2011-01-29           0.0             1.0               0.0
# 2011-01-29           0.0             1.0               0.0
# 2011-01-29           0.0             1.0               0.0
# 2011-01-29           0.0             1.0               0.0
# 2011-01-29           0.0             1.0               0.0
#
# [5 rows x 23 columns]

# %%
# Check unique values
print(f"The unique values for 'event_type_1' are {merge_df['event_type_1'].unique()}")

# Fit encoder
ohe.fit(merge_df[['event_type_1']]) 

# Display the detected categories
print(f"The categories detected by the OneHotEncoder are {ohe.categories_}")

# Display the generated names
print(f"The column names for the encoded values are {ohe.get_feature_names_out()}")

# Transform the current "cat_id" column
merge_df[ohe.get_feature_names_out()] = ohe.transform(merge_df[['event_type_1']])

# Drop the column "cat_id" which has been encoded
merge_df.drop(columns = ['event_type_1'], inplace = True)
# Out:
# The unique values for 'event_type_1' are ['missing' 'Sporting' 'Cultural' 'National' 'Religious']
# The categories detected by the OneHotEncoder are [array(['Cultural', 'National', 'Religious', 'Sporting', 'missing'],
#       dtype=object)]
# The column names for the encoded values are ['event_type_1_Cultural' 'event_type_1_National' 'event_type_1_Religious'
#  'event_type_1_Sporting' 'event_type_1_missing']

# %%
# Check unique values
print(f"The unique values for 'event_type_2' are {merge_df['event_type_2'].unique()}")

# Fit encoder
ohe.fit(merge_df[['event_type_2']]) 

# Display the detected categories
print(f"The categories detected by the OneHotEncoder are {ohe.categories_}")

# Display the generated names
print(f"The column names for the encoded values are {ohe.get_feature_names_out()}")

# Transform the current "cat_id" column
merge_df[ohe.get_feature_names_out()] = ohe.transform(merge_df[['event_type_2']])

# Drop the column "cat_id" which has been encoded
merge_df.drop(columns = ['event_type_2'], inplace = True)
# Out:
# The unique values for 'event_type_2' are ['missing' 'Cultural' 'Religious']
# The categories detected by the OneHotEncoder are [array(['Cultural', 'Religious', 'missing'], dtype=object)]
# The column names for the encoded values are ['event_type_2_Cultural' 'event_type_2_Religious' 'event_type_2_missing']

# %%
# Check unique values
print(f"The unique values for 'event_name_1' are {merge_df['event_name_1'].unique()}")

# Fit encoder
ohe.fit(merge_df[['event_name_1']]) 

# Display the detected categories
print(f"The categories detected by the OneHotEncoder are {ohe.categories_}")

# Display the generated names
print(f"The column names for the encoded values are {ohe.get_feature_names_out()}")

# Transform the current "cat_id" column
merge_df[ohe.get_feature_names_out()] = ohe.transform(merge_df[['event_name_1']])

# Drop the column "cat_id" which has been encoded
merge_df.drop(columns = ['event_name_1'], inplace = True)
# Out:
# The unique values for 'event_name_1' are ['missing' 'SuperBowl' 'ValentinesDay' 'PresidentsDay' 'LentStart'
#  'LentWeek2' 'StPatricksDay' 'Purim End' 'OrthodoxEaster' 'Pesach End'
#  'Cinco De Mayo' "Mother's day" 'MemorialDay' 'NBAFinalsStart'
#  'NBAFinalsEnd' "Father's day" 'IndependenceDay' 'Ramadan starts'
#  'Eid al-Fitr' 'LaborDay' 'ColumbusDay' 'Halloween' 'EidAlAdha'
#  'VeteransDay' 'Thanksgiving' 'Christmas' 'Chanukah End' 'NewYear'
#  'OrthodoxChristmas' 'MartinLutherKingDay' 'Easter']
# The categories detected by the OneHotEncoder are [array(['Chanukah End', 'Christmas', 'Cinco De Mayo', 'ColumbusDay',
#        'Easter', 'Eid al-Fitr', 'EidAlAdha', "Father's day", 'Halloween',
#        'IndependenceDay', 'LaborDay', 'LentStart', 'LentWeek2',
#        'MartinLutherKingDay', 'MemorialDay', "Mother's day",
#        'NBAFinalsEnd', 'NBAFinalsStart', 'NewYear', 'OrthodoxChristmas',
#        'OrthodoxEaster', 'Pesach End', 'PresidentsDay', 'Purim End',
#        'Ramadan starts', 'StPatricksDay', 'SuperBowl', 'Thanksgiving',
#        'ValentinesDay', 'VeteransDay', 'missing'], dtype=object)]
# The column names for the encoded values are ['event_name_1_Chanukah End' 'event_name_1_Christmas'
#  'event_name_1_Cinco De Mayo' 'event_name_1_ColumbusDay'
#  'event_name_1_Easter' 'event_name_1_Eid al-Fitr' 'event_name_1_EidAlAdha'
#  "event_name_1_Father's day" 'event_name_1_Halloween'
#  'event_name_1_IndependenceDay' 'event_name_1_LaborDay'
#  'event_name_1_LentStart' 'event_name_1_LentWeek2'
#  'event_name_1_MartinLutherKingDay' 'event_name_1_MemorialDay'
#  "event_name_1_Mother's day" 'event_name_1_NBAFinalsEnd'
#  'event_name_1_NBAFinalsStart' 'event_name_1_NewYear'
#  'event_name_1_OrthodoxChristmas' 'event_name_1_OrthodoxEaster'
#  'event_name_1_Pesach End' 'event_name_1_PresidentsDay'
#  'event_name_1_Purim End' 'event_name_1_Ramadan starts'
#  'event_name_1_StPatricksDay' 'event_name_1_SuperBowl'
#  'event_name_1_Thanksgiving' 'event_name_1_ValentinesDay'
#  'event_name_1_VeteransDay' 'event_name_1_missing']

# %%
# Check unique values
print(f"The unique values for 'event_name_2' are {merge_df['event_name_2'].unique()}")

# Fit encoder
ohe.fit(merge_df[['event_name_2']]) 

# Display the detected categories
print(f"The categories detected by the OneHotEncoder are {ohe.categories_}")

# Display the generated names
print(f"The column names for the encoded values are {ohe.get_feature_names_out()}")

# Transform the current "cat_id" column
merge_df[ohe.get_feature_names_out()] = ohe.transform(merge_df[['event_name_2']])

# Drop the column "cat_id" which has been encoded
merge_df.drop(columns = ['event_name_2'], inplace = True)
# Out:
# The unique values for 'event_name_2' are ['missing' 'Easter' 'Cinco De Mayo' 'OrthodoxEaster' "Father's day"]
# The categories detected by the OneHotEncoder are [array(['Cinco De Mayo', 'Easter', "Father's day", 'OrthodoxEaster',
#        'missing'], dtype=object)]
# The column names for the encoded values are ['event_name_2_Cinco De Mayo' 'event_name_2_Easter'
#  "event_name_2_Father's day" 'event_name_2_OrthodoxEaster'
#  'event_name_2_missing']

# %%
merge_df.head()
# Out:
#                                        id        item_id    dept_id store_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1     CA_1
#
#            state_id    d  sales  wm_yr_wk   weekday  wday  ...  \
# date                                                       ...
# 2011-01-29       CA  d_1     12     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      4     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      5     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      0     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      9     11101  Saturday     1  ...
#
#             event_name_1_SuperBowl  event_name_1_Thanksgiving  \
# date
# 2011-01-29                     0.0                        0.0
# 2011-01-29                     0.0                        0.0
# 2011-01-29                     0.0                        0.0
# 2011-01-29                     0.0                        0.0
# 2011-01-29                     0.0                        0.0
#
#             event_name_1_ValentinesDay  event_name_1_VeteransDay  \
# date
# 2011-01-29                         0.0                       0.0
# 2011-01-29                         0.0                       0.0
# 2011-01-29                         0.0                       0.0
# 2011-01-29                         0.0                       0.0
# 2011-01-29                         0.0                       0.0
#
#             event_name_1_missing  event_name_2_Cinco De Mayo  \
# date
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
#
#             event_name_2_Easter  event_name_2_Father's day  \
# date
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
#
#             event_name_2_OrthodoxEaster  event_name_2_missing
# date
# 2011-01-29                          0.0                   1.0
# 2011-01-29                          0.0                   1.0
# 2011-01-29                          0.0                   1.0
# 2011-01-29                          0.0                   1.0
# 2011-01-29                          0.0                   1.0
#
# [5 rows x 63 columns]

# %%
merge_df['wday'].value_counts()
# Out:
# wday
# 1    54800
# 2    54800
# 3    54600
# 4    54600
# 5    54600
# 6    54600
# 7    54600
# Name: count, dtype: int64

# %%
merge_df['weekday'].value_counts()
# Out:
# weekday
# Saturday     54800
# Sunday       54800
# Monday       54600
# Tuesday      54600
# Wednesday    54600
# Thursday     54600
# Friday       54600
# Name: count, dtype: int64

# %%
#Encoding Cyclical Features for weekdays
# Notice that Sat starts as 1 till Fri as 7 for 'wday'
merge_df['wday_sin'] = np.sin(2 * np.pi * merge_df['wday'] /7.0)
merge_df['wday_cos'] = np.cos(2 * np.pi * merge_df['wday'] /7.0)

# %%
#plt.figure(figsize=(10, 5))
plt.plot(merge_df['wday_sin'], merge_df['wday_cos'], label='weekdays')
plt.title('Cyclical Encoding of Weekdays')
plt.xlabel('Weekday')
plt.ylabel('Transformed Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Encoding Cyclical Features for month

merge_df['month_sin'] = np.sin(2 * np.pi * merge_df['month'] /12.0)
merge_df['month_cos'] = np.cos(2 * np.pi * merge_df['month'] /12.0)

# %%
#plt.figure(figsize=(10, 5))
plt.plot(merge_df['month_sin'], merge_df['month_cos'], label='month')
plt.title('Cyclical Encoding of months')
plt.xlabel('month')
plt.ylabel('Transformed Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
merge_df.head()
# Out:
#                                        id        item_id    dept_id store_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1     CA_1
#
#            state_id    d  sales  wm_yr_wk   weekday  wday  ...  \
# date                                                       ...
# 2011-01-29       CA  d_1     12     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      4     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      5     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      0     11101  Saturday     1  ...
# 2011-01-29       CA  d_1      9     11101  Saturday     1  ...
#
#             event_name_1_missing  event_name_2_Cinco De Mayo  \
# date
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
#
#             event_name_2_Easter  event_name_2_Father's day  \
# date
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
#
#             event_name_2_OrthodoxEaster  event_name_2_missing  wday_sin  \
# date
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
#
#             wday_cos  month_sin  month_cos
# date
# 2011-01-29   0.62349        0.5   0.866025
# 2011-01-29   0.62349        0.5   0.866025
# 2011-01-29   0.62349        0.5   0.866025
# 2011-01-29   0.62349        0.5   0.866025
# 2011-01-29   0.62349        0.5   0.866025
#
# [5 rows x 67 columns]

# %%
merge_df_scaled = merge_df.drop(columns=['d', 'wm_yr_wk','weekday'])

# %%
merge_df_scaled
# Out:
#                                        id        item_id    dept_id store_id  \
# date
# 2011-01-29  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_015_CA_1_validation  HOBBIES_1_015  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_016_CA_1_validation  HOBBIES_1_016  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_019_CA_1_validation  HOBBIES_1_019  HOBBIES_1     CA_1
# 2011-01-29  HOBBIES_1_032_CA_1_validation  HOBBIES_1_032  HOBBIES_1     CA_1
# ...                                   ...            ...        ...      ...
# 2016-04-24    FOODS_1_046_CA_2_validation    FOODS_1_046    FOODS_1     CA_2
# 2016-04-24    FOODS_1_055_CA_2_validation    FOODS_1_055    FOODS_1     CA_2
# 2016-04-24    FOODS_1_067_CA_2_validation    FOODS_1_067    FOODS_1     CA_2
# 2016-04-24    FOODS_1_085_CA_2_validation    FOODS_1_085    FOODS_1     CA_2
# 2016-04-24    FOODS_1_110_CA_2_validation    FOODS_1_110    FOODS_1     CA_2
#
#            state_id  sales  wday  month  year  snap_CA  ...  \
# date                                                    ...
# 2011-01-29       CA     12     1      1   0.0        0  ...
# 2011-01-29       CA      4     1      1   0.0        0  ...
# 2011-01-29       CA      5     1      1   0.0        0  ...
# 2011-01-29       CA      0     1      1   0.0        0  ...
# 2011-01-29       CA      9     1      1   0.0        0  ...
# ...             ...    ...   ...    ...   ...      ...  ...
# 2016-04-24       CA      8     2      4   1.0        0  ...
# 2016-04-24       CA      4     2      4   1.0        0  ...
# 2016-04-24       CA     15     2      4   1.0        0  ...
# 2016-04-24       CA     12     2      4   1.0        0  ...
# 2016-04-24       CA      0     2      4   1.0        0  ...
#
#             event_name_1_missing  event_name_2_Cinco De Mayo  \
# date
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# 2011-01-29                   1.0                         0.0
# ...                          ...                         ...
# 2016-04-24                   1.0                         0.0
# 2016-04-24                   1.0                         0.0
# 2016-04-24                   1.0                         0.0
# 2016-04-24                   1.0                         0.0
# 2016-04-24                   1.0                         0.0
#
#             event_name_2_Easter  event_name_2_Father's day  \
# date
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# 2011-01-29                  0.0                        0.0
# ...                         ...                        ...
# 2016-04-24                  0.0                        0.0
# 2016-04-24                  0.0                        0.0
# 2016-04-24                  0.0                        0.0
# 2016-04-24                  0.0                        0.0
# 2016-04-24                  0.0                        0.0
#
#             event_name_2_OrthodoxEaster  event_name_2_missing  wday_sin  \
# date
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# 2011-01-29                          0.0                   1.0  0.781831
# ...                                 ...                   ...       ...
# 2016-04-24                          0.0                   1.0  0.974928
# 2016-04-24                          0.0                   1.0  0.974928
# 2016-04-24                          0.0                   1.0  0.974928
# 2016-04-24                          0.0                   1.0  0.974928
# 2016-04-24                          0.0                   1.0  0.974928
#
#             wday_cos  month_sin  month_cos
# date
# 2011-01-29  0.623490   0.500000   0.866025
# 2011-01-29  0.623490   0.500000   0.866025
# 2011-01-29  0.623490   0.500000   0.866025
# 2011-01-29  0.623490   0.500000   0.866025
# 2011-01-29  0.623490   0.500000   0.866025
# ...              ...        ...        ...
# 2016-04-24 -0.222521   0.866025  -0.500000
# 2016-04-24 -0.222521   0.866025  -0.500000
# 2016-04-24 -0.222521   0.866025  -0.500000
# 2016-04-24 -0.222521   0.866025  -0.500000
# 2016-04-24 -0.222521   0.866025  -0.500000
#
# [382600 rows x 64 columns]

# %%
merge_df_scaled.to_csv("../raw_data/merge_df_scaled.csv",index=True)
